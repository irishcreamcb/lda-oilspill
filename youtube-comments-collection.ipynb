# %%
# %pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries
import pandas as pd 
import numpy as np
from googleapiclient.discovery import build
from dotenv import dotenv_values

# %%
# Set up API key and YouTube object
api_key = dotenv_values().get('API_KEY')
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# We use a YouTube video about the triple tanker oil spill in Manila Bay, from Kapuso mo, Jessica Soho.

# %%
video_id = '1iU7y20ZxyE'
video_response = youtube.commentThreads().list(
    videoId=video_id, 
    part='snippet,replies', 
    maxResults=300, 
    order='time', 
).execute()
video_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'XlngZp56JGEv2WNti_YtkWiIV_g',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNKMGdHQUVTQlFpSElCZ0FFZ1VJcUNBWUFCSUZDSWdnR0FBU0JRaUpJQmdBR0FBaURnb01DT1hpeDdVR0VJRG83SVVC',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Bg7f7Intx9SJTHt4auXEUvNFjYk',
#    'id': 'UgwI3MwQ0mJe6M_MQ_N4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NJBDmZQgAJyaYYhya--r0KeHpEo',
#      'id': 'UgwI3MwQ0mJe6M_MQ_N4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Tikom ang bibig ng mga nasa taas sa laki ng tapal ng SMC',
#       'textOriginal': 'Tikom ang bibig ng mga nasa taas sa laki ng tapal ng SMC',
#       'authorDisplayName': '@ryanjohndimaisip8136',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/BPT_WzK3_t5GOdgbnD7HApyYV9Y3FlMDTjMypo9VyGHAgfZH21PlDiXQIKKPdGKX1GJCvkspPg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ryanjohndimaisip8136',
#       'authorChannelId': {'value': 'UCKjk_VAXp44OqPAkT04rqaw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-23T02:16:14Z',
#       'updatedAt': '2024-08-23T02:16:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'p80K-tFRIxE9YPTneROmyRz8-_A',
#    'id': 'Ugydlk6goUWQszU82vx4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4PIzofj303ouRUPOaBV3QWRXhxQ',
#      'id': 'Ugydlk6goUWQszU82vx4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'dapat managot ung dapat managot dyn kapabayaan inuuna pa KC ung kaperahan ung kkitain',
#       'textOriginal': 'dapat managot ung dapat managot dyn kapabayaan inuuna pa KC ung kaperahan ung kkitain',
#       'authorDisplayName': '@marvinlorenzana8763',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lFlpOj9Nhb87XXViJQsi6JXtD4V_VKyj4TJgu0ND-3YtA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@marvinlorenzana8763',
#       'authorChannelId': {'value': 'UCPWRiPTVZTwZKMCTXgRIFaQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-13T12:04:57Z',
#       'updatedAt': '2024-08-13T12:04:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'D0DcWfcYoPMzknHqVgIjx-_Nrp4',
#    'id': 'UgxsJYInZkDtzLxZyU94AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'hGzN8f1eEKUti0WYzX48pAgw7xA',
#      'id': 'UgxsJYInZkDtzLxZyU94AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'perwisyo yan',
#       'textOriginal': 'perwisyo yan',
#       'authorDisplayName': '@marvinlorenzana8763',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lFlpOj9Nhb87XXViJQsi6JXtD4V_VKyj4TJgu0ND-3YtA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@marvinlorenzana8763',
#       'authorChannelId': {'value': 'UCPWRiPTVZTwZKMCTXgRIFaQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-13T12:01:15Z',
#       'updatedAt': '2024-08-13T12:01:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EXyRJyzoSP78awRg08L8pNz-YIw',
#    'id': 'UgwGX_twZNBeBI8ut4Z4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'S2jhurd7R6he2HPHZxLpM0PGnBg',
#      'id': 'UgwGX_twZNBeBI8ut4Z4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': '
AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Parang may gusto ipahiwatig ang mga pangyayari   sa smcorp😮',
#       'textOriginal': 'Parang may gusto ipahiwatig ang mga pangyayari   sa smcorp😮',
#       'authorDisplayName': '@maryroseumban3457',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_loJZ_Z2Ipsubc9w7_gapN2ObLEaujzXizxHxJ_iYGceg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@maryroseumban3457',
#       'authorChannelId': {'value': 'UCZ5ukl3jQgck_vcwx_kilPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-09T14:36:41Z',
#       'updatedAt': '2024-08-09T14:36:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'M5g5h3XBNOOKor2HkgV3zZFU1vE',
#    'id': 'UgzGNG_sjfPjlpYIGH94AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'B_B_Yllve8jfRXOOTbMkBZAzeQI',
#      'id': 'UgzGNG_sjfPjlpYIGH94AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Pag mahirap kulong pag mayaman o may kaya imbestigasyon awit sa inyo',
#       'textOriginal': 'Pag mahirap kulong pag mayaman o may kaya imbestigasyon awit sa inyo',
#       'authorDisplayName': '@romanlestersumague51',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m8BD2vy2yzy9UO-D5fZOf3Ybu3pRe9Ll2EPWMXbns=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@romanlestersumague51',
#       'authorChannelId': {'value': 'UCTyOkf5Fn8aDxrllFiW0kNQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-08-09T13:41:39Z',
#       'updatedAt': '2024-08-09T13:41:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xti0rGeqNI16mzFmov5VsZFd9Mo',
#    'id': 'Ugz_E5DDej8gMmySzOh4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EdaHD6840Eie3PgpmOrT928neAE',
#      'id': 'Ugz_E5DDej8gMmySzOh4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Ano Plano puro nalang ba dada walang gawa maawa naman kayo sa mga mangingisda bakit ayaw kasuhan ang mga owner ng mga barking tumaob',
#       'textOriginal': 'Ano Plano puro nalang ba dada walang gawa maawa naman kayo sa mga mangingisda bakit ayaw kasuhan ang mga owner ng mga barking tumaob',
#       'authorDisplayName': '@romanlestersumague51',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m8BD2vy2yzy9UO-D5fZOf3Ybu3pRe9Ll2EPWMXbns=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@romanlestersumague51',
#       'authorChannelId': {'value': 'UCTyOkf5Fn8aDxrllFiW0kNQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-09T13:40:31Z',
#       'updatedAt': '2024-08-09T13:40:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'euteHTQNRNmhvOmSklELX_k3o_8',
#    'id': 'UgwQqspU5Ay7wylyJOp4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'RjoqBUD12j-VYSMYt_xGjso7i_U',
#      'id': 'UgwQqspU5Ay7wylyJOp4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'I am seafarer sana patawan yan ng mabigat na parusa dahil Hnd yan dumaan sa complete documents ika nga tumakas naglayag at yan ang malaking consequences nangyri ngka oil spill nasisira ang yamang dagat at kabuhayan ng mga tao sa Lugar,,kaya for me, Sana patawan yan ng pnka mabigat na parusa includd na Yung Officer ng mga Vessel na yan...',
#       'textOriginal': 'I am seafarer sana patawan yan ng mabigat na parusa dahil Hnd yan dumaan sa complete documents ika nga tumakas naglayag at yan ang malaking consequences nangyri ngka oil spill nasisira ang yamang dagat at kabuhayan ng mga tao sa Lugar,,kaya for me, Sana patawan yan ng pnka mabigat na parusa includd na Yung Officer ng mga Vessel na yan...',
#       'authorDisplayName': '@user-nt6zm3mr6p',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/U_40LmoWuB4PVyIft33VBM_cZK6OPT2E6lb4_2Hymz7yHFkicJhw13QUDQoDQVk19-RHPeli=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-nt6zm3mr6p',
#       'authorChannelId': {'value': 'UCttQ2v_p4l00mzw7sA4xebA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-09T13:40:28Z',
#       'updatedAt': '2024-08-09T13:40:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'WYSaM9Rl669aoO63Ed75mGbikEU',
#    'id': 'UgzLlitv19OgtBmpS3N4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NasCPrhCvStxhsUIOlBo3SvkDxQ',
#      'id': 'UgzLlitv19OgtBmpS3N4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Ubos talaga lahat ng lamang dagat jan pagnagkataon',
#       'textOriginal': 'Ubos talaga lahat ng lamang dagat jan pagnagkataon',
#       'authorDisplayName': '@user-pk8qw3ui9m',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mNEAv5MPjwUYT_oMN-I_oKxZXRDcwTzQ5m2dLC8BLZIN_r2XL_arB8rM0NkGGWBLQJXQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-pk8qw3ui9m',
#       'authorChannelId': {'value': 'UCDKRdMAvjnSm894SZ578_UQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-09T12:16:31Z',
#       'updatedAt': '2024-08-09T12:16:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'cNGwVux-f9y32TABjK925raWKbA',
#    'id': 'Ugxg36Vfd49dW8wXnat4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Cya8OH74nG-8BqddIKy9ATo1dQQ',
#      'id': 'Ugxg36Vfd49dW8wXnat4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'dapat pagbayadin ang mga owner ng barko Nayan at ibigay sa mga mangingisda na apektado ...',
#       'textOriginal': 'dapat pagbayadin ang mga owner ng barko Nayan at ibigay sa mga mangingisda na apektado ...',
#       'authorDisplayName': '@patrickmanuel0917',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/KKivXYtU3Cxtz1qDICzCPeUjTMeMMS8p_mWW_KkVZWUvNK5DQAypWy2AAg0lXwpjd3vHx-pXRw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@patrickmanuel0917',
#       'authorChannelId': {'value': 'UCTV0L4Tcqk9xVrvF50267jw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-09T10:44:20Z',
#       'updatedAt': '2024-08-09T10:44:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CafDTZRljCUWEM0TyG6CE3fyxR0',
#    'id': 'UgzaEVESaCTVXbYYHi94AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'KAVKna6IFgMZafBHEeN4hg5qy70',
#      'id': 'UgzaEVESaCTVXbYYHi94AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'd naman mpapanagot ks san mig me  ari gaya ng nanyari noon pa sa visaya 😮😢😢',
#       'textOriginal': 'd naman mpapanagot ks san mig me  ari gaya ng nanyari noon pa sa visaya 😮😢😢',
#       'authorDisplayName': '@mandymocling4311',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kexSU46w6cYLAw7n2skj-kjy6uv4tRLz7Q3K1rsh5kWb6z0DWyfRdUElppkPxsBgt36Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@mandymocling4311',
#       'authorChannelId': {'value': 'UC0moEUUCqtY3ZnteksqUFkw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-09T09:35:16Z',
#       'updatedAt': '2024-08-09T09:35:16Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'bCp1ZZkjkGde93HfdgP9J8XVaqk',
#    'id': 'UgzyFGwHSNp02fDvQiN4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2tfF4a_KVed6EiiV_ebrAPU3VfQ',
#      'id': 'UgzyFGwHSNp02fDvQiN4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Super perwisyo talaga sa ilang mga baybayin at lalo na sa mga mangingisda',
#       'textOriginal': 'Super perwisyo talaga sa ilang mga baybayin at lalo na sa mga mangingisda',
#       'authorDisplayName': '@jeraldprado6243',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/YpYSx5bJTFKP-bcMmj1XV9teTdfI7k__9jQ9N1vveVnXLtERsP2aOzR4jPJHrmQf-F4lZVcx=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@
08Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'BthXH9nUwRCPhJFJ6dIqVd0lq20',
#    'id': 'UgyNmR-UnxvnWBA-cB94AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EGquimLjYDDy4ySKmpTX4Fp67bc',
#      'id': 'UgyNmR-UnxvnWBA-cB94AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Kung sino pa ung maliit kumita ng pera sila pa ung naperwisyo..',
#       'textOriginal': 'Kung sino pa ung maliit kumita ng pera sila pa ung naperwisyo..',
#       'authorDisplayName': '@aprilannjuanico8094',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kDlyjB2pE7tHiZxgDDD-4ITsXYMMphM8LsVgGY3aBvFQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@aprilannjuanico8094',
#       'authorChannelId': {'value': 'UCpzpL6C2gl81fn_oD3DSudw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-08T12:59:00Z',
#       'updatedAt': '2024-08-08T12:59:00Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'amEa1Ch-9PIq7jIibNYghoaIcUY',
#    'id': 'UgyiOwOMK-aN2SANc0J4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'WqWwrHImuXF1f-jNc2GXWdFF5cs',
#      'id': 'UgyiOwOMK-aN2SANc0J4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'we now have oily dolomite beaxh awit',
#       'textOriginal': 'we now have oily dolomite beaxh awit',
#       'authorDisplayName': '@Karl-KajkTV',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/dC2Jq7CudkoQYIgfpC9GXi7BMnWpNQmCAQUhg2gwTs-JlvHX3H2IC2XC4yEDYRHRHbtHC_3njg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Karl-KajkTV',
#       'authorChannelId': {'value': 'UCS01Dlr1n2cQXTcy_qCVcYg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-08T12:34:42Z',
#       'updatedAt': '2024-08-08T12:34:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'd93nYOkm3G0lo81n8YvMzeW1rLo',
#    'id': 'UgyfGBUgu2IcfeR73XF4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '3wS1dTjO9OAvz0YdmToMQorm7IY',
#      'id': 'UgyfGBUgu2IcfeR73XF4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'isa lang sulusyon.. pakalbo kayong lahat pinoy donate nyo buhok nyo para makatulong kayo',
#       'textOriginal': 'isa lang sulusyon.. pakalbo kayong lahat pinoy donate nyo buhok nyo para makatulong kayo',
#       'authorDisplayName': '@xd_kriss4403',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/p9dHLcG9UcGEC8IRjVUEIDXF5JAT8gU4EE82gBUke4oiI40A4TQlgGDU3xvqG6XmSRdclI_3=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@xd_kriss4403',
#       'authorChannelId': {'value': 'UC7MoBbY8nVE5YHU_H0HvbpA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-08T08:41:37Z',
#       'updatedAt': '2024-08-08T08:41:37Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'HRsV-LePF0wdVx1AbeYvCIyzltU',
#    'id': 'Ugy_C6Y0JA7Y1zv93vN4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'P0YdYacy-nhq6aUYV7S6wQGquJQ',
#      'id': 'Ugy_C6Y0JA7Y1zv93vN4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'naku natakot na si mama bumili ng isda dapat panagutan yang tatlo na yan mawawalan ng pagkain ang akong mga alagang aso patay sila sa akin',
#       'textOriginal': 'naku natakot na si mama bumili ng isda dapat panagutan yang tatlo na yan mawawalan ng pagkain ang akong mga alagang aso patay sila sa akin',
#       'authorDisplayName': '@JinxxStarlet',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/EXSjxrCzHZ4nAGCIlL-K9OtONp3r4w4FDWtBZbSnyqJ2kcB54R7cEYDceo5f1Ei4jzLJbZNgoA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@JinxxStarlet',
#       'authorChannelId': {'value': 'UCq_Fwg1_5HijwUC_uczQUEA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-08T08:26:01Z',
#       'updatedAt': '2024-08-08T08:26:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xij_frZt9RJ47o0xlAFPrgw8J60',
#    'id': 'UgxMl7_h-UkY7dL1onp4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '
AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'P7itwQdfi8yjMTd00ej7RBntav4',
#      'id': 'UgwNYbcYbz9BKQJYpfF4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Kalokohan! Di parin ako kakain ng isda sa mga susunod na linggo. 😅',
#       'textOriginal': 'Kalokohan! Di parin ako kakain ng isda sa mga susunod na linggo. 😅',
#       'authorDisplayName': '@agentblue52',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lVo33GgDyNTUqadI-M3VuynT2I6b3ZUr1Adm8ffa2kgLk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@agentblue52',
#       'authorChannelId': {'value': 'UCg9oclgUmOuNz0Yfv9WOk5g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-06T11:30:21Z',
#       'updatedAt': '2024-08-06T11:30:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_MQpX6aKbdOkR57Rgy4YU0x4zUI',
#    'id': 'UgzssPFs7BNJLvUu2El4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'A_i-5ZSiUKHrE2TP0yaQEGzFogg',
#      'id': 'UgzssPFs7BNJLvUu2El4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Itinago nga ng Panginoon sa ilalim ng dagat or lupa yung langis at diesel kasi alam ng Panginoon na nakakasira yun. Pero ano ginawa ng manga tao kinuha natin manga tao.',
#       'textOriginal': 'Itinago nga ng Panginoon sa ilalim ng dagat or lupa yung langis at diesel kasi alam ng Panginoon na nakakasira yun. Pero ano ginawa ng manga tao kinuha natin manga tao.',
#       'authorDisplayName': '@user-PobrengVloger28',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/D2HZybxLyZRNfwyvIiHhZDR7VNA8Kxtai0lDPVUgpXL2Osq2ZHW5H7tr099ZEFmCA-HVXErWAw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-PobrengVloger28',
#       'authorChannelId': {'value': 'UCTMBMnnbH_RRum5nqJMVX2g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-06T11:29:53Z',
#       'updatedAt': '2024-08-06T11:29:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '-cCk--JZMz02kqeqCrNd5sGWIv8',
#    'id': 'UgyqmHVCnlmifB02ixl4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tXsy3SFAA-HeBJV5AyqA14DoGqw',
#      'id': 'UgyqmHVCnlmifB02ixl4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Kapabayaan at mabagal na aksyon sobrang laki ng problema. Dapat pinagbabayad ang may ari ng mga tanker na yan dahil alam nilang may bagyo pero naglayag pa rin sila.',
#       'textOriginal': 'Kapabayaan at mabagal na aksyon sobrang laki ng problema. Dapat pinagbabayad ang may ari ng mga tanker na yan dahil alam nilang may bagyo pero naglayag pa rin sila.',
#       'authorDisplayName': '@YosoChannel-kv2vj',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/qJJWqYdJ2AlMrSIS4oRFbpaI8eEwd7QhsiFw6V6lDy29ueveNVZHKPsoUegci3pfcW5VosaBofE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@YosoChannel-kv2vj',
#       'authorChannelId': {'value': 'UCe5JZBIHzXk-rZGVHFutqCg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2024-08-06T11:28:56Z',
#       'updatedAt': '2024-08-06T11:28:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ozi7pY_X5a4zXbAEIDQ86dE__fE',
#    'id': 'UgwUcWWpTFBM18xmOtR4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'epOjX9Cq4b-DEa4ZijSQ86VNngM',
#      'id': 'UgwUcWWpTFBM18xmOtR4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': '😢😢😢',
#       'textOriginal': '😢😢😢',
#       'authorDisplayName': '@CharnaNacilla',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kr4bNGofmTMPp5MZXDPMJK5LVxode4q5XfL_KkDT6k-92DsDa2ZJkQL47K5Z7lphmMUw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@CharnaNacilla',
#       'authorChannelId': {'value': 'UCD0NmmC4zJAJWjxV1kU0iEQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-06T11:19:21Z',
#       'updatedAt': '2024-08-06T11:19:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '
AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Sayang mahal na nga ang Lang is tinatapon Lang ano klase utak n mayron cla',
#       'textOriginal': 'Sayang mahal na nga ang Lang is tinatapon Lang ano klase utak n mayron cla',
#       'authorDisplayName': '@normeniaabuela9169',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nzpKpa7fpQZX4ahMvzEZNvjLSKLIVDqBKkgeMBdDBePRg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@normeniaabuela9169',
#       'authorChannelId': {'value': 'UChOxfZNwUjRWaSxV-RUMQfw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-06T09:50:45Z',
#       'updatedAt': '2024-08-06T09:50:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'I8AEYolbkwNC518RcDWmJnz1Ayw',
#    'id': 'UgxpKEOpm1Y8rrgUJ8B4AaABAg',
#    'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#     'videoId': '1iU7y20ZxyE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8dHtEcueUjWy4jXMUnCB4Q0rnAw',
#      'id': 'UgxpKEOpm1Y8rrgUJ8B4AaABAg',
#      'snippet': {'channelId': 'UCj5RwDivLksanrNvkW0FB4w',
#       'videoId': '1iU7y20ZxyE',
#       'textDisplay': 'Sana ka tulad dini sa oriental Mindoro mabigyan din Ng karampatang kabayaran Ang mga na salanta Ng oilspill kawawa talaga Jan Ang mga mangi2sda😢',
#       'textOriginal': 'Sana ka tulad dini sa oriental Mindoro mabigyan din Ng karampatang kabayaran Ang mga na salanta Ng oilspill kawawa talaga Jan Ang mga mangi2sda😢',
#       'authorDisplayName': '@glenroseheven2130',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/KnNVhSHwLz0MKxncD7WjEflpisq9OUNms8VOPVN1EdotW4b2Uf5Y-WZSMsTfzseCUyw2FGiW=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@glenroseheven2130',
#       'authorChannelId': {'value': 'UCILz8Z07zFMdD9AeLmE-m7A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-06T09:48:22Z',
#       'updatedAt': '2024-08-06T09:48:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# In cases where there are more than 100 comments under the video, pagination is required to get the rest of them, since `.list()` only accepts a `maxResults` value of `0-100`. (more on this later)

# %% [markdown]
# Now we can inspect the elements of some comments in the list.

# %%
print(f'https://www.youtube.com/watch?v={video_id}&lc={video_response["items"][0]["snippet"]["topLevelComment"]["id"]}')
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['likeCount'])
# Out:
# https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwI3MwQ0mJe6M_MQ_N4AaABAg
# Tikom ang bibig ng mga nasa taas sa laki ng tapal ng SMC
# 2024-08-23T02:16:14Z
# Tikom ang bibig ng mga nasa taas sa laki ng tapal ng SMC
# 0

# %%
# Initialize storage for data
comments = [] 

# Iterate through the comments 
for item in video_response['items']: 

    comment = item['snippet']['topLevelComment']['snippet'] 

    comments.append([
        comment['textDisplay'],
        f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
        pd.to_datetime(comment['publishedAt']),
        comment['textOriginal'],
        comment['likeCount'],
        np.nan, # np.nan for parent_id column later on
    ])

    total_reply_count = item['snippet']['totalReplyCount'] 

    # Iterate through replies (kung meron) 
    if total_reply_count > 0: 
        parent_id = item['snippet']['topLevelComment']['id']

        replies = youtube.comments().list(
            part='snippet',
            parentId=parent_id, 
            maxResults=50,
        ).execute()

        for reply in replies['items']: 
            replyBody = reply['snippet'] 
            comments.append([
                replyBody['textDisplay'],
                f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
                replyBody['publishedAt'],
                replyBody['textOriginal'],
                replyBody['likeCount'],
                replyBody['parentId'],
            ])

comments
# Out:
# [['Tikom ang bibig ng mga nasa taas sa laki ng tapal ng SMC',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwI3MwQ0mJe6M_MQ_N4AaABAg',
#   Timestamp('2024-08-23 02:16:14+0000', tz='UTC'),
#   'Tikom ang bibig ng mga nasa taas sa laki ng tapal ng SMC',
#   0,
#   nan],
#  ['dapat managot ung dapat managot dyn kapabayaan inuuna pa KC ung kaperahan ung kkitain',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugydlk6goUWQszU82vx4AaABAg',
#   Timestamp('2024-08-13 12:04:57+0000', tz='UTC'),
#   'dapat managot ung dapat managot dyn kapabayaan inuuna pa KC ung kaperahan ung kkitain',
#   0,
#   nan],
#  ['perwisyo yan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxsJYInZkDtzLxZyU94AaABAg',
#   Timestamp('2024-08-13 12:01:15+0000', tz='UTC'),
#   'perwisyo yan',
#   0,
#   nan],
#  ['Ang dahilan ay Ng kbubuhan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwGX_twZNBeBI8ut4Z4AaABAg',
#   Timestamp('2024-08-12 09:35:56+0000', tz='UTC'),
#   'Ang dahilan ay Ng kbubuhan',
#   0,
#   nan],
#  ['Ai nko alam Ng may bagyo mga vompanya tlgang wlang kwenta mga mukhang pera',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwiADdpTOotuF9Q1d14AaABAg',
#   Timestamp('2024-08-11 11:40:17+0000', tz='UTC'),
#   'Ai nko alam Ng may bagyo mga vompanya tlgang wlang kwenta mga mukhang pera',
#   0,
#   nan],
#  ['Yun mirola parang hindi worthy mag layag',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugxs65yOJP2yKk4c1ht4AaABAg',
#   Timestamp('2024-08-11 08:16:01+0000', tz='UTC'),
#   'Yun mirola parang hindi worthy mag layag',
#   0,
#   nan],
#  ['Katigasan nang mga naglalayag na barko iyan. Iniisip ang pansariling kapakanan.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyvBlo-MF9vujBr02h4AaABAg',
#   Timestamp('2024-08-11 06:50:33+0000', tz='UTC'),
#   'Katigasan nang mga naglalayag na barko iyan. Iniisip ang pansariling kapakanan.',
#   0,
#   nan],
#  ['Diba nangyari nayan noon,ang ginawa ata nila noon nag buhos Sila nang madaming buhok don narin kakapit yong langis..',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyBOZUotSJf5_sowXl4AaABAg',
#   Timestamp('2024-08-11 02:02:45+0000', tz='UTC'),
#   'Diba nangyari nayan noon,ang ginawa ata nila noon nag buhos Sila nang madaming buhok don narin kakapit yong langis..',
#   0,
#   nan],
#  ['Go Philippines sirain nyo kalikasan nakakaproud kayong mga nasa nakaktaas',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxS3lVv2ualXHZ2eWB4AaABAg',
#   Timestamp('2024-08-10 01:12:57+0000', tz='UTC'),
#   'Go Philippines sirain nyo kalikasan nakakaproud kayong mga nasa nakaktaas',
#   0,
#   nan],
#  ['Asan na yung mga pinoy na tuwang tuwa nung bumagyo sa china.....God is not always love but God is Judge tignan nyo epekyo ng pagtawatawa nyo...tapos ngayon.hihingi kayo ng tulong kay God..',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyYDycFhM1mZBWdWLp4AaABAg',
#   Timestamp('2024-08-09 17:16:28+0000', tz='UTC'),
#   'Asan na yung mga pinoy na tuwang tuwa nung bumagyo sa china.....God is not always love but God is Judge tignan nyo epekyo ng pagtawatawa nyo...tapos ngayon.hihingi kayo ng tulong kay God..',
#   1,
#   nan],
#  ['Cge lang sirain nyo lang ang dagat....ibabalik din yan ng Dyos satin mga tao yan....lahat damay.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgztsqWV6bS5sdTvju94AaABAg',
#   Timestamp('2024-08-09 17:11:54+0000', tz='UTC'),
#   'Cge lang sirain nyo lang ang dagat....ibabalik din yan ng Dyos satin mga tao yan....lahat damay.',
#   1,
#   nan],
#  ['Parang may gusto ipahiwatig ang mga pangyayari   sa smcorp😮',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzvlFmHYTgbrDaCrSN4AaABAg',
#   Timestamp('2024-08-09 14:36:41+0000', tz='UTC'),
#   'Parang may gusto ipahiwatig ang mga pangyayari   sa smcorp😮',
#   0,
#   nan],
#  ['Pag mahirap kulong pag mayaman o may kaya imbestigasyon awit sa inyo',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzGNG_sjfPjlpYIGH94AaABAg',
#   Timestamp('2024-08-09 13:41:39+0000', tz='UTC'),
#   'Pag mahirap kulong pag mayaman o may kaya imbestigasyon awit sa inyo',
#   1,
#   nan],
#  ['Ano Plano puro nalang ba dada walang gawa maawa naman kayo sa mga mangingisda bakit ayaw kasuhan ang mga owner ng mga barking tumaob',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugz_E5DDej8gMmySzOh4AaABAg',
#   Timestamp('2024-08-09 13:40:31+0000', tz='UTC'),
#   'Ano Plano puro nalang ba dada walang gawa maawa naman kayo sa mga mangingisda bakit ayaw kasuhan ang mga owner ng mga barking tumaob',
#   0,
#   nan],
#  ['I am seafarer sana patawan yan ng mabigat na parusa dahil Hnd yan dumaan sa complete documents ika nga tumakas naglayag at yan ang malaking consequences nangyri ngka oil spill nasisira ang yamang dagat at kabuhayan ng mga tao sa Lugar,,kaya for me, Sana patawan yan ng pnka mabigat na parusa includd na Yung Officer ng mga Vessel na yan...',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwQqspU5Ay7wylyJOp4AaABAg',
#   Timestamp('2024-08-09 13:40:28+0000', tz='UTC'),
#   'I am seafarer sana patawan yan ng mabigat na parusa dahil Hnd yan dumaan sa complete documents ika nga tumakas naglayag at yan ang malaking consequences nangyri ngka oil spill nasisira ang yamang dagat at kabuhayan ng mga tao sa Lugar,,kaya for me, Sana patawan yan ng pnka mabigat na parusa includd na Yung Officer ng mga Vessel na yan...',
#   0,
#   nan],
#  ['Ubos talaga lahat ng lamang dagat jan pagnagkataon',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzLlitv19OgtBmpS3N4AaABAg',
#   Timestamp('2024-08-09 12:16:31+0000', tz='UTC'),
#   'Ubos talaga lahat ng lamang dagat jan pagnagkataon',
#   0,
#   nan],
#  ['dapat pagbayadin ang mga owner ng barko Nayan at ibigay sa mga mangingisda na apektado ...',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugxg36Vfd49dW8wXnat4AaABAg',
#   Timestamp('2024-08-09 10:44:20+0000', tz='UTC'),
#   'dapat pagbayadin ang mga owner ng barko Nayan at ibigay sa mga mangingisda na apektado ...',
#   0,
#   nan],
#  ['d naman mpapanagot ks san mig me  ari gaya ng nanyari noon pa sa visaya 😮😢😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzaEVESaCTVXbYYHi94AaABAg',
#   Timestamp('2024-08-09 09:35:16+0000', tz='UTC'),
#   'd naman mpapanagot ks san mig me  ari gaya ng nanyari noon pa sa visaya 😮😢😢',
#   0,
#   nan],
#  ['Super perwisyo talaga sa ilang mga baybayin at lalo na sa mga mangingisda',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzyFGwHSNp02fDvQiN4AaABAg',
#   Timestamp('2024-08-09 00:33:35+0000', tz='UTC'),
#   'Super perwisyo talaga sa ilang mga baybayin at lalo na sa mga mangingisda',
#   0,
#   nan],
#  ['Marcus bigyan ayuda mga mangingisda kawawa naman',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyLSrrIKHCG05Jo4G54AaABAg',
#   Timestamp('2024-08-08 22:39:04+0000', tz='UTC'),
#   'Marcus bigyan ayuda mga mangingisda kawawa naman',
#   0,
#   nan],
#  ['ang laking dagok nito sa mga mangingisda sa lugar na may oil spill 😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugw9r1fW_JuTgKSgz9t4AaABAg',
#   Timestamp('2024-08-08 18:03:10+0000', tz='UTC'),
#   'ang laking dagok nito sa mga mangingisda sa lugar na may oil spill 😢',
#   0,
#   nan],
#  ['Pati kami na mga taga dinahican infanta Quezon na lumalaot sa pacific Philippine rise na apiktuhan halos hindi na rin mabili mga isda namin dahil jn sa oil spill na yn eh ang layo naman ng manila bay sa linalaotan namin pero halos ayaw na rin bilihin mga isda dto lahat ng mga bangkang pamiwasan dto mga lugi kami nga kalahating milyon kunsomo namin tapos binta lang cguro namin nasa 300k 40 nalang kilo ng tulingan dto samin',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxttuUPhAcCASUC7gJ4AaABAg',
#   Timestamp('2024-08-08 14:22:41+0000', tz='UTC'),
#   'Pati kami na mga taga dinahican infanta Quezon na lumalaot sa pacific Philippine rise na apiktuhan halos hindi na rin mabili mga isda namin dahil jn sa oil spill na yn eh ang layo naman ng manila bay sa linalaotan namin pero halos ayaw na rin bilihin mga isda dto lahat ng mga bangkang pamiwasan dto mga lugi kami nga kalahating milyon kunsomo namin tapos binta lang cguro namin nasa 300k 40 nalang kilo ng tulingan dto samin',
#   0,
#   nan],
#  ['Kung sino pa ung maliit kumita ng pera sila pa ung naperwisyo..',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyNmR-UnxvnWBA-cB94AaABAg',
#   Timestamp('2024-08-08 12:59:00+0000', tz='UTC'),
#   'Kung sino pa ung maliit kumita ng pera sila pa ung naperwisyo..',
#   0,
#   nan],
#  ['we now have oily dolomite beaxh awit',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyiOwOMK-aN2SANc0J4AaABAg',
#   Timestamp('2024-08-08 12:34:42+0000', tz='UTC'),
#   'we now have oily dolomite beaxh awit',
#   0,
#   nan],
#  ['isa lang sulusyon.. pakalbo kayong lahat pinoy donate nyo buhok nyo para makatulong kayo',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyfGBUgu2IcfeR73XF4AaABAg',
#   Timestamp('2024-08-08 08:41:37+0000', tz='UTC'),
#   'isa lang sulusyon.. pakalbo kayong lahat pinoy donate nyo buhok nyo para makatulong kayo',
#   0,
#   nan],
#  ['naku natakot na si mama bumili ng isda dapat panagutan yang tatlo na yan mawawalan ng pagkain ang akong mga alagang aso patay sila sa akin',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugy_C6Y0JA7Y1zv93vN4AaABAg',
#   Timestamp('2024-08-08 08:26:01+0000', tz='UTC'),
#   'naku natakot na si mama bumili ng isda dapat panagutan yang tatlo na yan mawawalan ng pagkain ang akong mga alagang aso patay sila sa akin',
#   0,
#   nan],
#  ['Pagbayrin Ng malaki Yung COMPANY Ng lumubog na barko sa gobyerno pati mga apektadong mangingisda Sana. Both environment and kabuhayaan Yung nasira',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxMl7_h-UkY7dL1onp4AaABAg',
#   Timestamp('2024-08-08 05:44:28+0000', tz='UTC'),
#   'Pagbayrin Ng malaki Yung COMPANY Ng lumubog na barko sa gobyerno pati mga apektadong mangingisda Sana. Both environment and kabuhayaan Yung nasira',
#   0,
#   nan],
#  ['Nagkakaso na pala noon..bakit pa pinaglalayag mga yan.. perwisyo eh',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugw3iK8UsutLuAkNJyF4AaABAg',
#   Timestamp('2024-08-08 04:31:09+0000', tz='UTC'),
#   'Nagkakaso na pala noon..bakit pa pinaglalayag mga yan.. perwisyo eh',
#   0,
#   nan],
#  ['Halatang sinadya naman...kawawa nanaman ang ating kalikasan...',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugz2oGCIkycja_wcvjd4AaABAg',
#   Timestamp('2024-08-08 03:25:28+0000', tz='UTC'),
#   'Halatang sinadya naman...kawawa nanaman ang ating kalikasan...',
#   0,
#   nan],
#  ['mayron din kapitan na,kahit masama yong panahon pelit pa rin lalayag...',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgysDVzm9eyMpwjTS6J4AaABAg',
#   Timestamp('2024-08-08 02:20:24+0000', tz='UTC'),
#   'mayron din kapitan na,kahit masama yong panahon pelit pa rin lalayag...',
#   0,
#   nan],
#  ['Perwisyo talaga mga tanker na to alam na ngang may bagyo maglalayag pa sana pagbayarin mga yan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxHnyR2vgiyIF-pimR4AaABAg',
#   Timestamp('2024-08-08 01:54:35+0000', tz='UTC'),
#   'Perwisyo talaga mga tanker na to alam na ngang may bagyo maglalayag pa sana pagbayarin mga yan',
#   0,
#   nan],
#  ['niloloko mo naman kami jess and team nyo, sana nag inbestiga rin kayo sa other side, yung big fish na may ari o pinahihinalaang may ari, bait di nyo sila tinanung kung sa kanila yun, bakit, di nyo  imbestigahan ng mas malalim, bakit di nyo expose yung dating kaso ng spill, bakit, text lang yung paliwanag nyo sa mga may ari?',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgytOquFkHq5ERk-Fxl4AaABAg',
#   Timestamp('2024-08-07 20:57:17+0000', tz='UTC'),
#   'niloloko mo naman kami jess and team nyo, sana nag inbestiga rin kayo sa other side, yung big fish na may ari o pinahihinalaang may ari, bait di nyo sila tinanung kung sa kanila yun, bakit, di nyo  imbestigahan ng mas malalim, bakit di nyo expose yung dating kaso ng spill, bakit, text lang yung paliwanag nyo sa mga may ari?',
#   0,
#   nan],
#  ['Why not Americans come to the rescue',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzVs7N6SyzPSpNFHzl4AaABAg',
#   Timestamp('2024-08-07 17:59:12+0000', tz='UTC'),
#   'Why not Americans come to the rescue',
#   0,
#   nan],
#  ['Ang tanung bkit pinayagan??? Ang sagot jn my palaman yan pag nag pa clearance 😂 ung pandisal na my palaman na cheese!!',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugy3Q9h_laATCmwBwZV4AaABAg',
#   Timestamp('2024-08-07 16:28:16+0000', tz='UTC'),
#   'Ang tanung bkit pinayagan??? Ang sagot jn my palaman yan pag nag pa clearance 😂 ung pandisal na my palaman na cheese!!',
#   0,
#   nan],
#  ['Bgyan ng ayuda ang mangingisda o naapektuhan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyWQtZKeLEbus1iZqd4AaABAg',
#   Timestamp('2024-08-07 12:48:40+0000', tz='UTC'),
#   'Bgyan ng ayuda ang mangingisda o naapektuhan',
#   0,
#   nan],
#  ['President sisihin nyan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxWhgLy6J5RNlMQxwV4AaABAg',
#   Timestamp('2024-08-07 12:29:38+0000', tz='UTC'),
#   'President sisihin nyan',
#   1,
#   nan],
#  ['Presidente nanaman juskooo!',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxWhgLy6J5RNlMQxwV4AaABAg.A6q6Dy5pFhAA6q7g2Sqmp6',
#   '2024-08-07T12:42:21Z',
#   'Presidente nanaman juskooo!',
#   0,
#   'UgxWhgLy6J5RNlMQxwV4AaABAg'],
#  ['Kawawa naman yung mga apektadong mangingisda. Anu kaya yung gagawing aksyon ng gobyerno dito.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxX896CexedCr4lMXF4AaABAg',
#   Timestamp('2024-08-07 12:15:54+0000', tz='UTC'),
#   'Kawawa naman yung mga apektadong mangingisda. Anu kaya yung gagawing aksyon ng gobyerno dito.',
#   0,
#   nan],
#  ['San Miguel nnmn?<br>Sila dn ung umaangkin ng lupa ng mga katutubo sa Balabac right?',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugx4d34UJjspdPMYY-Z4AaABAg',
#   Timestamp('2024-08-07 10:45:33+0000', tz='UTC'),
#   'San Miguel nnmn?\nSila dn ung umaangkin ng lupa ng mga katutubo sa Balabac right?',
#   0,
#   nan],
#  ['Desaster na yan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxWzM-nfxbgdYbNpo94AaABAg',
#   Timestamp('2024-08-07 08:15:26+0000', tz='UTC'),
#   'Desaster na yan',
#   0,
#   nan],
#  ['D kya ito sinadya NG China kc Alam mo nman yang China walang kasing sama',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugz8C4XW8aQZjl6A5Yd4AaABAg',
#   Timestamp('2024-08-07 08:14:34+0000', tz='UTC'),
#   'D kya ito sinadya NG China kc Alam mo nman yang China walang kasing sama',
#   0,
#   nan],
#  ['Yong mga mangingisda na sa dagat lang umaasa..kawawa nman',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugw-GqAFvFHQ2dtruU14AaABAg',
#   Timestamp('2024-08-07 06:55:07+0000', tz='UTC'),
#   'Yong mga mangingisda na sa dagat lang umaasa..kawawa nman',
#   0,
#   nan],
#  ['Government galaw galaw maawa kayo sa mga mamamayan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugx6YjCSkwiQ3-PmEvR4AaABAg',
#   Timestamp('2024-08-07 04:27:22+0000', tz='UTC'),
#   'Government galaw galaw maawa kayo sa mga mamamayan',
#   0,
#   nan],
#  ['Taga mariveles Bataan po Ako at Isa po Akosa mga nagtitinda ng isda Dito sa mariveles ..sobrang matumal po dahil maraming natatakot dhil sa oil spill ...ang hirap mag paubus lagi maraming Tira',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugx2QTF8hlIE0YAhrTF4AaABAg',
#   Timestamp('2024-08-07 04:23:05+0000', tz='UTC'),
#   'Taga mariveles Bataan po Ako at Isa po Akosa mga nagtitinda ng isda Dito sa mariveles ..sobrang matumal po dahil maraming natatakot dhil sa oil spill ...ang hirap mag paubus lagi maraming Tira',
#   3,
#   nan],
#  ['😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugx2QTF8hlIE0YAhrTF4AaABAg.A6pEYLdIfkRA6pFLAJi0BG',
#   '2024-08-07T04:30:01Z',
#   '😢',
#   0,
#   'Ugx2QTF8hlIE0YAhrTF4AaABAg'],
#  ['HAHAHAHAHA INANG PHIL COAST GUARD TO NAPAKAWALANG KWENTA KURAP NA AHENSYA TALAGA HAHAHAHAHA',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxzZR-lRJHJc9SICOx4AaABAg',
#   Timestamp('2024-08-07 04:09:39+0000', tz='UTC'),
#   'HAHAHAHAHA INANG PHIL COAST GUARD TO NAPAKAWALANG KWENTA KURAP NA AHENSYA TALAGA HAHAHAHAHA',
#   0,
#   nan],
#  ['the tankers should be held liable and they should help clean up their <br>mess!',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwAl-c888_JlWUFhVZ4AaABAg',
#   Timestamp('2024-08-07 04:09:03+0000', tz='UTC'),
#   'the tankers should be held liable and they should help clean up their \nmess!',
#   6,
#   nan],
#  ['Bago na naman iyan?',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyWmEaTooOt09RTkhd4AaABAg',
#   Timestamp('2024-08-07 02:05:47+0000', tz='UTC'),
#   'Bago na naman iyan?',
#   0,
#   nan],
#  ['Wala na pag asa ang Pilipinas',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugy1r5p8FwvorW_RQ7Z4AaABAg',
#   Timestamp('2024-08-06 23:53:04+0000', tz='UTC'),
#   'Wala na pag asa ang Pilipinas',
#   0,
#   nan],
#  ['Mga taga amaya tanza mag ingay!!!! 😁😁',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzH1cFqGg8jzE-63Ep4AaABAg',
#   Timestamp('2024-08-06 23:13:06+0000', tz='UTC'),
#   'Mga taga amaya tanza mag ingay!!!! 😁😁',
#   0,
#   nan],
#  ['D kaya gawa ng china yan baka sinuholan yong nag dala ng barko na ilubog sa dagat kapalit ng malaking halaga...kc sunod²x na yan eh...',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwUUE7NRLnbkVeedE54AaABAg',
#   Timestamp('2024-08-06 22:16:07+0000', tz='UTC'),
#   'D kaya gawa ng china yan baka sinuholan yong nag dala ng barko na ilubog sa dagat kapalit ng malaking halaga...kc sunod²x na yan eh...',
#   1,
#   nan],
#  ['sabi ng coast guard under control lahat yan at secure na lahat sa interview ni ted failon sa tagapag salita yata yun 😢😢😢😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugx_qnx_mhRJRbEUZ7p4AaABAg',
#   Timestamp('2024-08-06 21:36:16+0000', tz='UTC'),
#   'sabi ng coast guard under control lahat yan at secure na lahat sa interview ni ted failon sa tagapag salita yata yun 😢😢😢😢',
#   0,
#   nan],
#  ['Yan ang patunay at enodensya 😂😂😂😂😂',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugy1EV5hbMy4pakPYWh4AaABAg',
#   Timestamp('2024-08-06 21:34:23+0000', tz='UTC'),
#   'Yan ang patunay at enodensya 😂😂😂😂😂',
#   0,
#   nan],
#  ['alam na gawa ng &#39; &#39; CHINA &#39; &#39; para malihis ang balita kay alice guo.... isip isip pinas baka may binayaran ang china pra gawin yan....',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxhaiQ8SrOVuAIr-c14AaABAg',
#   Timestamp('2024-08-06 21:12:42+0000', tz='UTC'),
#   "alam na gawa ng ' ' CHINA ' ' para malihis ang balita kay alice guo.... isip isip pinas baka may binayaran ang china pra gawin yan....",
#   0,
#   nan],
#  ['grabe purwisyo.. kawawa mga mangingisda agmamahal ang mga bilihin din na seafood sigurado.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugy-AlqpRiFVffflb1V4AaABAg',
#   Timestamp('2024-08-06 20:02:25+0000', tz='UTC'),
#   'grabe purwisyo.. kawawa mga mangingisda agmamahal ang mga bilihin din na seafood sigurado.',
#   0,
#   nan],
#  ['Dpat ung nkuha sa pogo dto nyo itulong suskooooooo wla tlga kaunlaran now sa mga nakaupo 🤦🏼\u200d♀️🤦🏼\u200d♀️🤦🏼\u200d♀️',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwiLQpcCu6Zrbrff7d4AaABAg',
#   Timestamp('2024-08-06 18:38:08+0000', tz='UTC'),
#   'Dpat ung nkuha sa pogo dto nyo itulong suskooooooo wla tlga kaunlaran now sa mga nakaupo 🤦🏼\u200d♀️🤦🏼\u200d♀️🤦🏼\u200d♀️',
#   0,
#   nan],
#  ['Nsan si bbm',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxMss5ChnrfH-9rF0t4AaABAg',
#   Timestamp('2024-08-06 18:32:27+0000', tz='UTC'),
#   'Nsan si bbm',
#   1,
#   nan],
#  ['Dpat kung sno may ari ng mga barko cla mag tanggal ng oil spill.. Gastusan dn nla.. bgyan dn ng trabho mga affected na mangingisda ar ayuda',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugxmf0FhyrM4bsLNMdp4AaABAg',
#   Timestamp('2024-08-06 16:59:40+0000', tz='UTC'),
#   'Dpat kung sno may ari ng mga barko cla mag tanggal ng oil spill.. Gastusan dn nla.. bgyan dn ng trabho mga affected na mangingisda ar ayuda',
#   0,
#   nan],
#  ['Ito ang patunay na nag kamali ako ng piniling pangulo. Sabagay walang mapag kakatiwalaan ng panahon na yan. Ngayon pinakita na mismo ng kalamidad na sinungaling kang pangulo. Tama nga ang sabi na hindi magagawa ng anak ang ginawa ng kanyang ama. Ikaw ang walang awa leader ng bansa ngayon. Hindi filipino ang kalaban mo. Sinira mo lng lalo ang legasiya ng iyung ama.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugzizp1nX-F7xmLqWad4AaABAg',
#   Timestamp('2024-08-06 16:55:07+0000', tz='UTC'),
#   'Ito ang patunay na nag kamali ako ng piniling pangulo. Sabagay walang mapag kakatiwalaan ng panahon na yan. Ngayon pinakita na mismo ng kalamidad na sinungaling kang pangulo. Tama nga ang sabi na hindi magagawa ng anak ang ginawa ng kanyang ama. Ikaw ang walang awa leader ng bansa ngayon. Hindi filipino ang kalaban mo. Sinira mo lng lalo ang legasiya ng iyung ama.',
#   0,
#   nan],
#  ['Mgka2sunod 3 na barko ???? Conspiracy or natural accident ????',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxmN-tjAdBKs0lUP2h4AaABAg',
#   Timestamp('2024-08-06 16:22:12+0000', tz='UTC'),
#   'Mgka2sunod 3 na barko ???? Conspiracy or natural accident ????',
#   0,
#   nan],
#  ['dapat ung may ari ng mga barko cla mag sustento ngaun sa mga naapektuhan mangingisda',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzM1sgZMsc92iVxVql4AaABAg',
#   Timestamp('2024-08-06 16:05:16+0000', tz='UTC'),
#   'dapat ung may ari ng mga barko cla mag sustento ngaun sa mga naapektuhan mangingisda',
#   1,
#   nan],
#  ['Kapitan Nagpumilit bumyahe dahil takot sa demorahe..  nalaman ng VTMS  kaya Pinabalik sila Sa bataan Dun nadali sila ng Alon..<br><br>Tanong bakit binigyan Ng PCG CLEARANCE  alam na masama ang Panahon at habagat na that time..<br><br>Monitored namin sa CH. 16  dahil nagsisigawan na sa radio  habang nalubog...',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxaB7_W-LVSlExgWuR4AaABAg',
#   Timestamp('2024-08-06 15:41:45+0000', tz='UTC'),
#   'Kapitan Nagpumilit bumyahe dahil takot sa demorahe..  nalaman ng VTMS  kaya Pinabalik sila Sa bataan Dun nadali sila ng Alon..\n\nTanong bakit binigyan Ng PCG CLEARANCE  alam na masama ang Panahon at habagat na that time..\n\nMonitored namin sa CH. 16  dahil nagsisigawan na sa radio  habang nalubog...',
#   0,
#   nan],
#  ['Dapat managot Ang mga companya n may ari Ng mga barko n Yan puro pkinabang na lang Ang iniisip mgpayaman,kawawa Ang mga maliliit na tao',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgydtvyP66GdnTTIzL94AaABAg',
#   Timestamp('2024-08-06 15:30:49+0000', tz='UTC'),
#   'Dapat managot Ang mga companya n may ari Ng mga barko n Yan puro pkinabang na lang Ang iniisip mgpayaman,kawawa Ang mga maliliit na tao',
#   0,
#   nan],
#  ['Kmjs mag senador kanalang iboboto kita..',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugw2ETym79BoeTL0FKd4AaABAg',
#   Timestamp('2024-08-06 15:22:45+0000', tz='UTC'),
#   'Kmjs mag senador kanalang iboboto kita..',
#   0,
#   nan],
#  ['Iba tlaga ang batas sa pinas pag may kaya ang tagal ng imbestigasyon kahit nanjan na ang kapabyaan ng mga companya pero pag mahihirap kulong kaagad 😢😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyEqh4gl4SGUFd4Kw94AaABAg',
#   Timestamp('2024-08-06 15:17:53+0000', tz='UTC'),
#   'Iba tlaga ang batas sa pinas pag may kaya ang tagal ng imbestigasyon kahit nanjan na ang kapabyaan ng mga companya pero pag mahihirap kulong kaagad 😢😢',
#   12,
#   nan],
#  ['Baka may sumasabutahi sa bansa natin..',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxyeC-h_AwQ-OUMGBx4AaABAg',
#   Timestamp('2024-08-06 15:17:28+0000', tz='UTC'),
#   'Baka may sumasabutahi sa bansa natin..',
#   0,
#   nan],
#  ['Kung mahihirap ang mga nakasala kulong kaagad pero itoy mga malalaking companya kailangan pa ng imbestigasyon? E klaro na ang kapabayaan ng mga companyang yan 😒',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwzmHtLvy_REHyAja54AaABAg',
#   Timestamp('2024-08-06 15:15:49+0000', tz='UTC'),
#   'Kung mahihirap ang mga nakasala kulong kaagad pero itoy mga malalaking companya kailangan pa ng imbestigasyon? E klaro na ang kapabayaan ng mga companyang yan 😒',
#   0,
#   nan],
#  ['ung tumakas at di nbigyan ng clearance pero naglayag pa dn, hold them accountable! they should compensate ung mga mangingisdang naapektuhan ang kabuhayan!',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugwnf-hS7oASyT3Kb_V4AaABAg',
#   Timestamp('2024-08-06 15:11:00+0000', tz='UTC'),
#   'ung tumakas at di nbigyan ng clearance pero naglayag pa dn, hold them accountable! they should compensate ung mga mangingisdang naapektuhan ang kabuhayan!',
#   0,
#   nan],
#  ['Dapat mga ganitong bagay tumutulong ang US navy HINDI yung pakikipag giyera 🙄🙄🙄',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxXnYPULVoOGSw9H8V4AaABAg',
#   Timestamp('2024-08-06 14:28:35+0000', tz='UTC'),
#   'Dapat mga ganitong bagay tumutulong ang US navy HINDI yung pakikipag giyera 🙄🙄🙄',
#   0,
#   nan],
#  ['Nasa senado nnman yan mag tuturuan?? Hahaha',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwVlLbF-0hd_Dno7nR4AaABAg',
#   Timestamp('2024-08-06 14:28:34+0000', tz='UTC'),
#   'Nasa senado nnman yan mag tuturuan?? Hahaha',
#   0,
#   nan],
#  ['Kaya hnd Tayo n udlad Kasi kahit ano nangyare xa buhay natin e sisi xa government Kaya hnd Tayo n onlad hnd natin gayahin ang mga katabi natin n bansa puro Tayo paninira',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwXMA42d6KHpWz1jUx4AaABAg',
#   Timestamp('2024-08-06 13:50:59+0000', tz='UTC'),
#   'Kaya hnd Tayo n udlad Kasi kahit ano nangyare xa buhay natin e sisi xa government Kaya hnd Tayo n onlad hnd natin gayahin ang mga katabi natin n bansa puro Tayo paninira',
#   0,
#   nan],
#  ['Patakan nyo ng JOY',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugy9QLtS8gVi_TsFM-Z4AaABAg',
#   Timestamp('2024-08-06 13:48:39+0000', tz='UTC'),
#   'Patakan nyo ng JOY',
#   0,
#   nan],
#  ['Ang bagyo at ang mga corrupt n opisyales',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzfKkEWiiBXjdZj52l4AaABAg',
#   Timestamp('2024-08-06 13:48:29+0000', tz='UTC'),
#   'Ang bagyo at ang mga corrupt n opisyales',
#   0,
#   nan],
#  ['Ang dapat managot diyan eh yung mga kapitan ng barko.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzDjnrXGH3CfqkFLJR4AaABAg',
#   Timestamp('2024-08-06 13:42:28+0000', tz='UTC'),
#   'Ang dapat managot diyan eh yung mga kapitan ng barko.',
#   0,
#   nan],
#  ['Magtulungan Kasi sanhi Ng kalamidad walang my gus2 Nyan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxjDpT1ru4UHVfw1GB4AaABAg',
#   Timestamp('2024-08-06 13:28:55+0000', tz='UTC'),
#   'Magtulungan Kasi sanhi Ng kalamidad walang my gus2 Nyan',
#   0,
#   nan],
#  ['sa ginawa mo na yan mam damay ibang mangingisda kahit wala sa kanila oil spill mga bulastog',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugxdw8z8ltWqCsg3WIl4AaABAg',
#   Timestamp('2024-08-06 13:25:05+0000', tz='UTC'),
#   'sa ginawa mo na yan mam damay ibang mangingisda kahit wala sa kanila oil spill mga bulastog',
#   0,
#   nan],
#  ['bulastog talaga  damay ung galing sa ibang lugar ginutum mo lal9 mga ibang magdaragat',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxGYrleNn7AlR8bIh14AaABAg',
#   Timestamp('2024-08-06 13:23:45+0000', tz='UTC'),
#   'bulastog talaga  damay ung galing sa ibang lugar ginutum mo lal9 mga ibang magdaragat',
#   0,
#   nan],
#  ['Panagutin dapat',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugw2NunVg0Df2e-e8214AaABAg',
#   Timestamp('2024-08-06 13:14:44+0000', tz='UTC'),
#   'Panagutin dapat',
#   0,
#   nan],
#  ['dito naman sa Batangas lugi ang magbababoy gawa ng ASF..',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugy1Pdem9kHFs6dh0f54AaABAg',
#   Timestamp('2024-08-06 13:07:47+0000', tz='UTC'),
#   'dito naman sa Batangas lugi ang magbababoy gawa ng ASF..',
#   0,
#   nan],
#  ['Petron daw sabi nung matanda sa video',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugzlp-MNrgfS7fRTStR4AaABAg',
#   Timestamp('2024-08-06 13:04:46+0000', tz='UTC'),
#   'Petron daw sabi nung matanda sa video',
#   0,
#   nan],
#  ['Tuwang tuwa naman yung mga galit sa Manila bay. <br>Alam niyo na sino sila. <br>😊',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwD6XmpleFL8S80bz54AaABAg',
#   Timestamp('2024-08-06 13:02:27+0000', tz='UTC'),
#   'Tuwang tuwa naman yung mga galit sa Manila bay. \nAlam niyo na sino sila. \n😊',
#   0,
#   nan],
#  ['ano na SMC bingi pa din ba?',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugx4bPS7QbRNOMq_RqN4AaABAg',
#   Timestamp('2024-08-06 12:57:07+0000', tz='UTC'),
#   'ano na SMC bingi pa din ba?',
#   0,
#   nan],
#  ['Mamimigay nang ayuda Ang gubyerno sana makarating sa taong naapektuhan nang oils peel Hindi sa bulsa nang mag nanakaw na pulitiko',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxInkxB5mIzOF6lyZR4AaABAg',
#   Timestamp('2024-08-06 12:54:07+0000', tz='UTC'),
#   'Mamimigay nang ayuda Ang gubyerno sana makarating sa taong naapektuhan nang oils peel Hindi sa bulsa nang mag nanakaw na pulitiko',
#   0,
#   nan],
#  ['Kaya pala wag daw Muna komain ng isda',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwFTNqsBKES-6zqr814AaABAg',
#   Timestamp('2024-08-06 12:47:39+0000', tz='UTC'),
#   'Kaya pala wag daw Muna komain ng isda',
#   0,
#   nan],
#  ['Sobrang luma na Kasi, pumapasa para gamitin.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzNCiLIbIrgpG2RPtN4AaABAg',
#   Timestamp('2024-08-06 12:41:23+0000', tz='UTC'),
#   'Sobrang luma na Kasi, pumapasa para gamitin.',
#   0,
#   nan],
#  ['Dapat pinag bayad ng danyos yang may ari ng mga barko sa lahat ng nanjan sa tabing dagat kasi naapectuhan ang hanap buhay nila at kalusugan jan dilikado kasi yang oil spill,,,',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugx4wDECdzIKFRG0IeJ4AaABAg',
#   Timestamp('2024-08-06 12:39:52+0000', tz='UTC'),
#   'Dapat pinag bayad ng danyos yang may ari ng mga barko sa lahat ng nanjan sa tabing dagat kasi naapectuhan ang hanap buhay nila at kalusugan jan dilikado kasi yang oil spill,,,',
#   0,
#   nan],
#  ['Pera pera lng yan',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyIhkockKiYK4XOBN94AaABAg',
#   Timestamp('2024-08-06 12:37:24+0000', tz='UTC'),
#   'Pera pera lng yan',
#   0,
#   nan],
#  ['Yung kita sa kanila,, yung perwisyo sa taong bayan at sa tax ng pilipino 🤬🤬🤬tsk tsk tsk',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyXF4Kq3vKcGNwNwm14AaABAg',
#   Timestamp('2024-08-06 12:10:11+0000', tz='UTC'),
#   'Yung kita sa kanila,, yung perwisyo sa taong bayan at sa tax ng pilipino 🤬🤬🤬tsk tsk tsk',
#   0,
#   nan],
#  ['Nakakayamot manood Ng mga ganto, Ang Tatanga Ng mga ganyan pabaya',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugxp3CXfHmgMuequOXx4AaABAg',
#   Timestamp('2024-08-06 11:56:36+0000', tz='UTC'),
#   'Nakakayamot manood Ng mga ganto, Ang Tatanga Ng mga ganyan pabaya',
#   10,
#   nan],
#  ['2026 malapit na ipanganak yung bagong species ng isda na kumakain ng langis',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwgETQaVP3luPpsZqN4AaABAg',
#   Timestamp('2024-08-06 11:47:43+0000', tz='UTC'),
#   '2026 malapit na ipanganak yung bagong species ng isda na kumakain ng langis',
#   0,
#   nan],
#  ['eto dpat ang e modernized ng gobyerno ang mga inter island vessel',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzH8JK4ty3ldJPV2t14AaABAg',
#   Timestamp('2024-08-06 11:39:01+0000', tz='UTC'),
#   'eto dpat ang e modernized ng gobyerno ang mga inter island vessel',
#   0,
#   nan],
#  ['Dapat tutukan. Ito ng Governo bgyan cla ng tulong. Apektuhan ang Mangisda. Ang kabuhayan nila 😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxruoeZHMMim_WwLEx4AaABAg',
#   Timestamp('2024-08-06 11:32:52+0000', tz='UTC'),
#   'Dapat tutukan. Ito ng Governo bgyan cla ng tulong. Apektuhan ang Mangisda. Ang kabuhayan nila 😢',
#   0,
#   nan],
#  ['Nako PAANO na Yan Ang mangingisda at Ang langis Sana makuha na agad.mamamatay Ang nga isda Niya 😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyO2PpNvlyzbDQAEpJ4AaABAg',
#   Timestamp('2024-08-06 11:32:26+0000', tz='UTC'),
#   'Nako PAANO na Yan Ang mangingisda at Ang langis Sana makuha na agad.mamamatay Ang nga isda Niya 😢',
#   0,
#   nan],
#  ['Kalokohan! Di parin ako kakain ng isda sa mga susunod na linggo. 😅',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwNYbcYbz9BKQJYpfF4AaABAg',
#   Timestamp('2024-08-06 11:30:21+0000', tz='UTC'),
#   'Kalokohan! Di parin ako kakain ng isda sa mga susunod na linggo. 😅',
#   0,
#   nan],
#  ['Itinago nga ng Panginoon sa ilalim ng dagat or lupa yung langis at diesel kasi alam ng Panginoon na nakakasira yun. Pero ano ginawa ng manga tao kinuha natin manga tao.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzssPFs7BNJLvUu2El4AaABAg',
#   Timestamp('2024-08-06 11:29:53+0000', tz='UTC'),
#   'Itinago nga ng Panginoon sa ilalim ng dagat or lupa yung langis at diesel kasi alam ng Panginoon na nakakasira yun. Pero ano ginawa ng manga tao kinuha natin manga tao.',
#   0,
#   nan],
#  ['Kapabayaan at mabagal na aksyon sobrang laki ng problema. Dapat pinagbabayad ang may ari ng mga tanker na yan dahil alam nilang may bagyo pero naglayag pa rin sila.',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgyqmHVCnlmifB02ixl4AaABAg',
#   Timestamp('2024-08-06 11:28:56+0000', tz='UTC'),
#   'Kapabayaan at mabagal na aksyon sobrang laki ng problema. Dapat pinagbabayad ang may ari ng mga tanker na yan dahil alam nilang may bagyo pero naglayag pa rin sila.',
#   2,
#   nan],
#  ['😢😢😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwUcWWpTFBM18xmOtR4AaABAg',
#   Timestamp('2024-08-06 11:19:21+0000', tz='UTC'),
#   '😢😢😢',
#   0,
#   nan],
#  ['Jusmiyo marimar ung claims nmin dito sa Mindoro dpa naibibigay tas ayan na nman my god....',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=Ugzr9a4JmYAOrpTX10J4AaABAg',
#   Timestamp('2024-08-06 11:10:19+0000', tz='UTC'),
#   'Jusmiyo marimar ung claims nmin dito sa Mindoro dpa naibibigay tas ayan na nman my god....',
#   0,
#   nan],
#  ['Kung sa ibang bansa nangyare ito kulong na agad ang kapitan multa na may community service pa, then magmumulta rin ang company or owner ng barko kasama narin ang charter party, pero syempre iba ang pinas dahil sa korupsyon 😂 PCG giseng paano nakalusot ang owner ng barko at charterer?? Gising pilipinas',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwA0Ev_rqE3VY5meMJ4AaABAg',
#   Timestamp('2024-08-06 10:57:00+0000', tz='UTC'),
#   'Kung sa ibang bansa nangyare ito kulong na agad ang kapitan multa na may community service pa, then magmumulta rin ang company or owner ng barko kasama narin ang charter party, pero syempre iba ang pinas dahil sa korupsyon 😂 PCG giseng paano nakalusot ang owner ng barko at charterer?? Gising pilipinas',
#   0,
#   nan],
#  ['Sana yong mga kompanya na mayari ng mga barko nayan singinlin dahil sa ipikto ng oilspell sa dagat kita nila may bagyo nako kawawa nman yong mga magigisda na malapit sa oilspeel',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgzgpI21SACi9maWODJ4AaABAg',
#   Timestamp('2024-08-06 10:36:04+0000', tz='UTC'),
#   'Sana yong mga kompanya na mayari ng mga barko nayan singinlin dahil sa ipikto ng oilspell sa dagat kita nila may bagyo nako kawawa nman yong mga magigisda na malapit sa oilspeel',
#   0,
#   nan],
#  ['Sayang mahal na nga ang Lang is tinatapon Lang ano klase utak n mayron cla',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgwYxgc5_Amq4trYJ7N4AaABAg',
#   Timestamp('2024-08-06 09:50:45+0000', tz='UTC'),
#   'Sayang mahal na nga ang Lang is tinatapon Lang ano klase utak n mayron cla',
#   0,
#   nan],
#  ['Sana ka tulad dini sa oriental Mindoro mabigyan din Ng karampatang kabayaran Ang mga na salanta Ng oilspill kawawa talaga Jan Ang mga mangi2sda😢',
#   'https://www.youtube.com/watch?v=1iU7y20ZxyE&lc=UgxpKEOpm1Y8rrgUJ8B4AaABAg',
#   Timestamp('2024-08-06 09:48:22+0000', tz='UTC'),
#   'Sana ka tulad dini sa oriental Mindoro mabigyan din Ng karampatang kabayaran Ang mga na salanta Ng oilspill kawawa talaga Jan Ang mga mangi2sda😢',
#   0,
#   nan]]

# %%
youtube_corpus = pd.DataFrame(
    comments, columns=['snippet','link','date_published','text','like_count','reply_parent_id',]
)
youtube_corpus
# Out:
#                                                snippet  \
# 0    Tikom ang bibig ng mga nasa taas sa laki ng ta...
# 1    dapat managot ung dapat managot dyn kapabayaan...
# 2                                         perwisyo yan
# 3                           Ang dahilan ay Ng kbubuhan
# 4    Ai nko alam Ng may bagyo mga vompanya tlgang w...
# ..                                                 ...
# 97   Jusmiyo marimar ung claims nmin dito sa Mindor...
# 98   Kung sa ibang bansa nangyare ito kulong na aga...
# 99   Sana yong mga kompanya na mayari ng mga barko ...
# 100  Sayang mahal na nga ang Lang is tinatapon Lang...
# 101  Sana ka tulad dini sa oriental Mindoro mabigya...
#
#                                                   link  \
# 0    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 1    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 2    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 3    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 4    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# ..                                                 ...
# 97   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 98   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 99   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 100  https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 101  https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
#
#                 date_published  \
# 0    2024-08-23 02:16:14+00:00
# 1    2024-08-13 12:04:57+00:00
# 2    2024-08-13 12:01:15+00:00
# 3    2024-08-12 09:35:56+00:00
# 4    2024-08-11 11:40:17+00:00
# ..                         ...
# 97   2024-08-06 11:10:19+00:00
# 98   2024-08-06 10:57:00+00:00
# 99   2024-08-06 10:36:04+00:00
# 100  2024-08-06 09:50:45+00:00
# 101  2024-08-06 09:48:22+00:00
#
#                                                   text  like_count  \
# 0    Tikom ang bibig ng mga nasa taas sa laki ng ta...           0
# 1    dapat managot ung dapat managot dyn kapabayaan...           0
# 2                                         perwisyo yan           0
# 3                           Ang dahilan ay Ng kbubuhan           0
# 4    Ai nko alam Ng may bagyo mga vompanya tlgang w...           0
# ..                                                 ...         ...
# 97   Jusmiyo marimar ung claims nmin dito sa Mindor...           0
# 98   Kung sa ibang bansa nangyare ito kulong na aga...           0
# 99   Sana yong mga kompanya na mayari ng mga barko ...           0
# 100  Sayang mahal na nga ang Lang is tinatapon Lang...           0
# 101  Sana ka tulad dini sa oriental Mindoro mabigya...           0
#
#     reply_parent_id
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 97              NaN
# 98              NaN
# 99              NaN
# 100             NaN
# 101             NaN
#
# [102 rows x 6 columns]

# %%
# Maximum number of comments we want 
no_comments = 500 

# Re-initialize the data structures 
comments = []
youtube_corpus = None 

video_id = '1iU7y20ZxyE'
video_response = youtube.commentThreads().list(
    videoId=video_id, 
    part='snippet,replies', 
    maxResults=300, 
    order='time', 
    moderationStatus='published',
).execute()

while len(comments) < no_comments: 
    for item in video_response['items']: 

        comment = item['snippet']['topLevelComment']['snippet'] 

        comments.append([
            comment['textDisplay'],
            f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
            pd.to_datetime(comment['publishedAt']),
            comment['textOriginal'],
            comment['likeCount'],
            np.nan, # np.nan for parent_id column later on
        ])

        total_reply_count = item['snippet']['totalReplyCount'] 

        # Iterate through replies (kung meron) 
        if total_reply_count > 0: 
            parent_id = item['snippet']['topLevelComment']['id']

            replies = youtube.comments().list(
                part='snippet',
                parentId=parent_id, 
                maxResults=50,
            ).execute()

            for reply in replies['items']: 
                replyBody = reply['snippet'] 
                comments.append([
                    replyBody['textDisplay'],
                    f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
                    replyBody['publishedAt'],
                    replyBody['textOriginal'],
                    replyBody['likeCount'],
                    replyBody['parentId'],
                ])

    print(str(len(comments)) + ' comments currently in list.') 

    if 'nextPageToken' in video_response: 
        # Notify user that there is another page of comments 
        print('Next comment page found. Now extracting data.')

        video_response = youtube.commentThreads().list(
            videoId=video_id, 
            part='snippet,replies', 
            maxResults=100, 
            order='time', 
            pageToken=video_response['nextPageToken'], 
            moderationStatus='published'
        ).execute() 

    else: 
        # Notify user that there is no more page of comments
        print('No more comment pages left.') 
        break
# Out:
# 102 comments currently in list.
# Next comment page found. Now extracting data.
# 212 comments currently in list.
# Next comment page found. Now extracting data.
# 286 comments currently in list.
# No more comment pages left.

# %%
youtube_corpus = pd.DataFrame(
    comments, columns=['snippet','link','date_published','text','like_count','reply_parent_id',]
)
youtube_corpus
# Out:
#                                                snippet  \
# 0    Tikom ang bibig ng mga nasa taas sa laki ng ta...
# 1    dapat managot ung dapat managot dyn kapabayaan...
# 2                                         perwisyo yan
# 3                           Ang dahilan ay Ng kbubuhan
# 4    Ai nko alam Ng may bagyo mga vompanya tlgang w...
# ..                                                 ...
# 281  bakit ung mga bahay sobrang lapit sa dagat? de...
# 282  sismio naman dysn myo gamitin ang pera para sa...
# 283  Hindi nila kayang bumili ng lupa para patayuan...
# 284                            parang may duda aq jn ,
# 285                                           sinadya?
#
#                                                   link  \
# 0    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 1    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 2    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 3    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 4    https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# ..                                                 ...
# 281  https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 282  https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 283  https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 284  https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 285  https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
#
#                 date_published  \
# 0    2024-08-23 02:16:14+00:00
# 1    2024-08-13 12:04:57+00:00
# 2    2024-08-13 12:01:15+00:00
# 3    2024-08-12 09:35:56+00:00
# 4    2024-08-11 11:40:17+00:00
# ..                         ...
# 281  2024-08-05 17:13:48+00:00
# 282       2024-08-06T18:32:11Z
# 283       2024-08-07T10:03:02Z
# 284  2024-08-05 16:07:17+00:00
# 285       2024-08-05T21:14:49Z
#
#                                                   text  like_count  \
# 0    Tikom ang bibig ng mga nasa taas sa laki ng ta...           0
# 1    dapat managot ung dapat managot dyn kapabayaan...           0
# 2                                         perwisyo yan           0
# 3                           Ang dahilan ay Ng kbubuhan           0
# 4    Ai nko alam Ng may bagyo mga vompanya tlgang w...           0
# ..                                                 ...         ...
# 281  bakit ung mga bahay sobrang lapit sa dagat? de...           8
# 282  sismio naman dysn myo gamitin ang pera para sa...           0
# 283  Hindi nila kayang bumili ng lupa para patayuan...           0
# 284                            parang may duda aq jn ,           3
# 285                                           sinadya?           1
#
#                 reply_parent_id
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 281                         NaN
# 282  UgweJfmNtRkNg7X7IaJ4AaABAg
# 283  UgweJfmNtRkNg7X7IaJ4AaABAg
# 284                         NaN
# 285  UgwybgNMtGD45Qmd6BF4AaABAg
#
# [286 rows x 6 columns]

# %%
def extract_youtube_comments(video_id: str, no_comments: int) -> pd.DataFrame:
    comments = []

    video_response = youtube.commentThreads().list(
        videoId=video_id, 
        part='snippet,replies', 
        maxResults=50, 
        order='time', 
        moderationStatus='published',
    ).execute()

    while len(comments) < no_comments: 
        for item in video_response['items']: 

            comment = item['snippet']['topLevelComment']['snippet'] 

            comments.append([
                comment['textDisplay'],
                f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
                pd.to_datetime(comment['publishedAt']),
                comment['textOriginal'],
                comment['likeCount'],
                np.nan, # np.nan for parent_id column later on
            ])

            total_reply_count = item['snippet']['totalReplyCount'] 

            # Iterate through replies (kung meron) 
            if total_reply_count > 0: 
                parent_id = item['snippet']['topLevelComment']['id']

                replies = youtube.comments().list(
                    part='snippet',
                    parentId=parent_id, 
                    maxResults=50,
                ).execute()

                for reply in replies['items']: 
                    replyBody = reply['snippet'] 
                    comments.append([
                        replyBody['textDisplay'],
                        f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
                        replyBody['publishedAt'],
                        replyBody['textOriginal'],
                        replyBody['likeCount'],
                        replyBody['parentId'],
                    ])

        print(str(len(comments)) + ' comments currently in list.') 

        if 'nextPageToken' in video_response: 
            # Notify user that there is another page of comments 
            print('Next comment page found. Now extracting data.')

            video_response = youtube.commentThreads().list(
                videoId=video_id, 
                part='snippet,replies', 
                maxResults=50, 
                order='time', 
                pageToken=video_response['nextPageToken'], 
                moderationStatus='published'
            ).execute() 

        else: 
            # Notify user that there is no more page of comments
            print('No more comment pages left.') 
            break

    return pd.DataFrame(
        comments, columns=['snippet','link','date_published','text','like_count','reply_parent_id',]
    )

# %%
video_links = [
    '1iU7y20ZxyE', # GMA 
    'etVZ1VMn71Y',
    '4avFPtdvb94',
    'JMoBBoD-fhY',
    'RKlGfbNZXfU', 
    'TMkdWSojbNg',
    'YHTib7Piwp0', 
    'waLpAM584Eo', 
    'NGoYiqTSMH8', 
    'zdGImljmcFk', # UNTV 
    'NpwJLXoXt2s', 
    'g3wqZkggxOg', 
    'IYeLMmI9Ksc',
    'prSpeRfzFjE', 
    'qg7vmTErqcA',  
    'GHXgXzfI24U', 
    'XxqkuhaBgE4', # ABS-CBN 
    'NokWiHAhTsY', 
    'X__RPRS3qc8', 
    'h-6C67AcRaE', 
    'Uro5rtCgWRM', # Rappler 
    'caG8Bk5t2wo', # Inquirer
    'gjBqQMfA_FA', 
    'dN4Ip02WThA', # Philstar
    'EIgzv5eRnn8', # Manila Bulletin 
    'IwMq11lT6hk', # ANC 24/7
    '6CRVc9YI-yc', # The Manila Times 
    'ZKV6Fpt3Mdg', # DW News (german news outlet)
    'eGt7L_dEvlo', 
]

oilspill_youtube_corpus = None

for video_link in video_links: 
    print(f'\nExtracting comments from https://www.youtube.com/watch?v={video_link}')
    if oilspill_youtube_corpus is None: 
        oilspill_youtube_corpus = extract_youtube_comments(video_link, 300)
    else: 
        oilspill_youtube_corpus = pd.concat([
            oilspill_youtube_corpus, extract_youtube_comments(video_link, 300)
        ])

oilspill_youtube_corpus
# Out:
# Extracting comments from https://www.youtube.com/watch?v=1iU7y20ZxyE
# 52 comments currently in list.
# Next comment page found. Now extracting data.
# 102 comments currently in list.
# Next comment page found. Now extracting data.
# 154 comments currently in list.
# Next comment page found. Now extracting data.
# 212 comments currently in list.
# Next comment page found. Now extracting data.
# 286 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=etVZ1VMn71Y
# 6 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=4avFPtdvb94
# 12 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=JMoBBoD-fhY
# 2 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=RKlGfbNZXfU
# 14 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=TMkdWSojbNg
# 7 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=YHTib7Piwp0
# 9 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=waLpAM584Eo
# 9 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=NGoYiqTSMH8
# 20 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=zdGImljmcFk
# 17 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=NpwJLXoXt2s
# 6 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=g3wqZkggxOg
# 10 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=IYeLMmI9Ksc
# 10 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=prSpeRfzFjE
# 44 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=qg7vmTErqcA
# 51 comments currently in list.
# Next comment page found. Now extracting data.
# 91 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=GHXgXzfI24U
# 16 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=XxqkuhaBgE4
# 12 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=NokWiHAhTsY
# 2 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=X__RPRS3qc8
# 6 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=h-6C67AcRaE
# 9 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=Uro5rtCgWRM
# 26 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=caG8Bk5t2wo
# 4 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=gjBqQMfA_FA
# 4 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=dN4Ip02WThA
# 38 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=EIgzv5eRnn8
# 26 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=IwMq11lT6hk
# 12 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=6CRVc9YI-yc
# 21 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=ZKV6Fpt3Mdg
# 106 comments currently in list.
# No more comment pages left.
#
# Extracting comments from https://www.youtube.com/watch?v=eGt7L_dEvlo
# 63 comments currently in list.
# Next comment page found. Now extracting data.
# 99 comments currently in list.
# No more comment pages left.
#                                               snippet  \
# 0   Tikom ang bibig ng mga nasa taas sa laki ng ta...
# 1   dapat managot ung dapat managot dyn kapabayaan...
# 2                                        perwisyo yan
# 3                          Ang dahilan ay Ng kbubuhan
# 4   Ai nko alam Ng may bagyo mga vompanya tlgang w...
# ..                                                ...
# 94               And man will destroy his own domain.
# 95  Years ago I heard that a GMO bacteria has been...
# 96  Crude oil is no different from cooking oil. Th...
# 97  I feel for you brothers .. respect Australian ...
# 98  they were still reeling and dealing oil price ...
#
#                                                  link  \
# 0   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 1   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 2   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 3   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# 4   https://www.youtube.com/watch?v=1iU7y20ZxyE&lc...
# ..                                                ...
# 94  https://www.youtube.com/watch?v=eGt7L_dEvlo&lc...
# 95  https://www.youtube.com/watch?v=eGt7L_dEvlo&lc...
# 96  https://www.youtube.com/watch?v=eGt7L_dEvlo&lc...
# 97  https://www.youtube.com/watch?v=eGt7L_dEvlo&lc...
# 98  https://www.youtube.com/watch?v=eGt7L_dEvlo&lc...
#
#                date_published  \
# 0   2024-08-23 02:16:14+00:00
# 1   2024-08-13 12:04:57+00:00
# 2   2024-08-13 12:01:15+00:00
# 3   2024-08-12 09:35:56+00:00
# 4   2024-08-11 11:40:17+00:00
# ..                        ...
# 94  2024-07-29 12:55:11+00:00
# 95  2024-07-29 12:48:46+00:00
# 96       2024-07-29T21:46:19Z
# 97  2024-07-29 12:47:02+00:00
# 98       2024-07-30T11:32:12Z
#
#                                                  text  like_count  \
# 0   Tikom ang bibig ng mga nasa taas sa laki ng ta...           0
# 1   dapat managot ung dapat managot dyn kapabayaan...           0
# 2                                        perwisyo yan           0
# 3                          Ang dahilan ay Ng kbubuhan           0
# 4   Ai nko alam Ng may bagyo mga vompanya tlgang w...           0
# ..                                                ...         ...
# 94               And man will destroy his own domain.          17
# 95  Years ago I heard that a GMO bacteria has been...           1
# 96  Crude oil is no different from cooking oil. Th...           0
# 97  I feel for you brothers .. respect Australian ...          14
# 98  they were still reeling and dealing oil price ...           0
#
#                reply_parent_id
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 94                         NaN
# 95                         NaN
# 96  UgyQxE3-2_87y00FKJh4AaABAg
# 97                         NaN
# 98  Ugze5BF7eCqYirrvMGJ4AaABAg
#
# [924 rows x 6 columns]

# %%
oilspill_youtube_corpus.to_csv('oilspill-comments.csv')
